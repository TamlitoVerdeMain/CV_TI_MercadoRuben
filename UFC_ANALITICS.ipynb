# %% [markdown]
# <a href="https://colab.research.google.com/github/TamlitoVerdeMain/CV_TI_MercadoRuben/blob/main/UFC_ANALITICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

path = '/content/ufc-master.csv'

ds_ufc= pd.read_csv(path)
forma=ds_ufc.shape
print ( forma)
print(ds_ufc.dtypes)
# Out:
# (7177, 118)
# R_fighter      object
# B_fighter      object
# R_odds        float64
# B_odds        float64
# R_ev          float64
#                ...
# b_dec_odds    float64
# r_sub_odds    float64
# b_sub_odds    float64
# r_ko_odds     float64
# b_ko_odds     float64
# Length: 118, dtype: object

# %%
ds_ufc['Ranking_Banta'] = ds_ufc['B_Bantamweight_rank']

print (ds_ufc['B_Bantamweight_rank'].head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1959/2431983365.py in <cell line: 0>()
# ----> 1 ds_ufc['Ranking Banta'] = ds_ufc['B_Bantamweight_rank'] != NaN
#       2
#       3 print (ds_ufc['B_Bantamweight_rank'].head(10))
#
# NameError: name 'NaN' is not defined
